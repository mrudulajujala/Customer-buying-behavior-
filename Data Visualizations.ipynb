# %%
# %matplotlib inline
pd.crosstab(Ecom_Data.Gender,Ecom_Data.FACT__1).plot(kind='bar')
plt.title(' customer satisfaction')
plt.xlabel('gender')
plt.ylabel('satisfaction')
#############################################################################
From the above graph we observed that in each factor Males are strongly agree
#############################################################################

# %matplotlib inline
pd.crosstab(Ecom_Data.Gender,Ecom_Data.FACT__2).plot(kind='bar')
plt.title(' customer satisfaction')
plt.xlabel('gender')
plt.ylabel('satisfaction')

# %matplotlib inline
pd.crosstab(Ecom_Data.Gender,Ecom_Data.FACT__3).plot(kind='bar')
plt.title(' customer satisfaction')
plt.xlabel('gender')
plt.ylabel('satisfaction')

# %matplotlib inline
pd.crosstab(Ecom_Data.Gender,Ecom_Data.FACT__4).plot(kind='bar')
plt.title(' customer satisfaction')
plt.xlabel('gender')
plt.ylabel('satisfaction')

# %matplotlib inline
pd.crosstab(Ecom_Data.Gender,Ecom_Data.CBB_9).plot(kind='bar')
plt.title(' customer satisfaction')
plt.xlabel('gender')
plt.ylabel('satisfaction')

# %matplotlib inline
pd.crosstab(Ecom_Data.Gender,Ecom_Data.CBB_10).plot(kind='bar')
plt.title(' customer satisfaction')
plt.xlabel('gender')
plt.ylabel('satisfaction')

# %matplotlib inline
pd.crosstab(Ecom_Data.Gender,Ecom_Data.CBB_11).plot(kind='bar')
plt.title(' customer satisfaction')
plt.xlabel('gender')
plt.ylabel('satisfaction')

# %matplotlib inline
pd.crosstab(Ecom_Data.Gender,Ecom_Data.CBB_12).plot(kind='bar')
plt.title(' customer satisfaction')
plt.xlabel('gender')
plt.ylabel('satisfaction')

# %matplotlib inline
pd.crosstab(Ecom_Data.Gender,Ecom_Data.CBB_13).plot(kind='bar')
plt.title(' customer satisfaction')
plt.xlabel('gender')
plt.ylabel('satisfaction')

# %matplotlib inline
pd.crosstab(Ecom_Data.Gender,Ecom_Data.CBB_14).plot(kind='bar')
plt.title(' customer satisfaction')
plt.xlabel('gender')
plt.ylabel('satisfaction')

#############################################################################
Encoding
#############################################################################

# New code # using label encoder & for loop converting to factors above defined columns
lb_make = LabelEncoder()
for i in range(y):
    Ey_Data[Ecom_Data.columns[i]] = lb_make.fit_transform(Ey_Data[Ecom_Data.columns[i]])
    i+=1
print("its done")

Ey_Data.columns

Ey_Data.head()
