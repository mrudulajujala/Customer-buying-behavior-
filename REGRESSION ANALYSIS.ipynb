# %%
##Implementing Model ( Multilinear Regression)##

Y=Ey_Data["Gender"]

################FIRST 15FACTS
X1=Ey_Data[['CBB_9', 'CBB_10', 'CBB_11', 'CBB_12', 'CBB_13', 'CBB_14','FACT__1', 'FACT__2', 'FACT__3', 'FACT__4', 'FACT__5', 'FACT__6','FACT__7', 'FACT__8', 'FACT__9', 'FACT__10', 'FACT__11', 'FACT__12','FACT__13', 'FACT__14', 'FACT__15']]

# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X1, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

X1 = sm.add_constant(X1) # adding a constant
 
model = sm.OLS(Y, X1).fit()
predictions = model.predict(X1) 
 
print_model = model.summary()
print(print_model)

#############NEXT 15FACTS
X2=Ey_Data[['CBB_9', 'CBB_10', 'CBB_11', 'CBB_12', 'CBB_13', 'CBB_14' ,'FACT__16', 'FACT__17', 'FACT__18','FACT__19', 'FACT__20', 'FACT__21', 'FACT__22', 'FACT__23', 'FACT__24','FACT__25', 'FACT__26', 'FACT__27', 'FACT__28', 'FACT__29', 'FACT__30']]

# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X2, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

X2 = sm.add_constant(X2) # adding a constant
 
model = sm.OLS(Y, X2).fit()
predictions = model.predict(X2) 
 
print_model = model.summary()
print(print_model)

X=Ey_Data[['CBB_9', 'CBB_10', 'CBB_11', 'CBB_12', 'CBB_13', 'CBB_14','FACT__1', 'FACT__2', 'FACT__3', 'FACT__4', 'FACT__5', 'FACT__6','FACT__7', 'FACT__8', 'FACT__9', 'FACT__10', 'FACT__11', 'FACT__12','FACT__13', 'FACT__14', 'FACT__15', 'FACT__16', 'FACT__17', 'FACT__18','FACT__19', 'FACT__20', 'FACT__21', 'FACT__22', 'FACT__23', 'FACT__24','FACT__25', 'FACT__26', 'FACT__27', 'FACT__28', 'FACT__29', 'FACT__30']]

regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)

# %%
#############################################################################
Logistic Regression
#############################################################################

###FACT1 TO FACT15
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
X_train, X_test, y_train, y_test = train_test_split(X1,Y, test_size=0.3, random_state=0)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
