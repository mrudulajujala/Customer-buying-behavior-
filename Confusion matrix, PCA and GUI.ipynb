# %%
#############################################################################
Confusion Matrix
#############################################################################

from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

#######FACT16 TO FACT30
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
X_train, X_test, y_train, y_test = train_test_split(X2,Y, test_size=0.3, random_state=0)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))

from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

#FACT1 TO FACT30
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=0)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))

from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
#############################################################################
PCA
#############################################################################

#####FACT_1 TO  FACT_15
from sklearn.preprocessing import StandardScaler
features = Ey_Data[['CBB_9', 'CBB_10', 'CBB_11', 'CBB_12', 'CBB_13', 'CBB_14','FACT__1', 'FACT__2', 'FACT__3', 'FACT__4', 'FACT__5', 'FACT__6','FACT__7', 'FACT__8', 'FACT__9', 'FACT__10', 'FACT__11', 'FACT__12','FACT__13', 'FACT__14', 'FACT__15','FACT__16', 'FACT__17', 'FACT__18','FACT__19', 'FACT__20', 'FACT__21', 'FACT__22', 'FACT__23', 'FACT__24','FACT__25', 'FACT__26', 'FACT__27', 'FACT__28', 'FACT__29', 'FACT__30']]
features

# Separating out the features
x =features
# Separating out the target
y = Ey_Data['Gender']
# Standardizing the features
x = StandardScaler().fit_transform(x)

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalComponents

principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
principalDf

finalDf = pd.concat([principalDf,Ecom_Data [['Gender']]], axis = 1)
finalDf

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 30)
targets = ['Female','Male']
colors = ['r', 'g']
for Gender, color in zip(targets,colors):
    indicesToKeep = finalDf['Gender'] == Gender
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 20)
ax.legend(targets)

pca.explained_variance_ratio_

# Creating test- Train splits
x_train1,x_test1,y_train1,y_test1=train_test_split(finalDf[["principal component 1","principal component 2"]],finalDf["Gender"],test_size=0.2,random_state=0)
x_train1.head()

x_test1

# create the claassifier
logreg=LogisticRegression(random_state = 0)
#fit the classifier to the training data
logreg.fit(x_train1,y_train1)

# Predicting the test set result using  
# predict function under LogisticRegression  
y_pred = logreg.predict(x_test1)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(x_test1, y_test1)))

# %%
#############################################################################
Confusion Matrix
#############################################################################
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test1, y_pred)
print(confusion_matrix)

#############################################################################
The result is telling us that we have 35+40 currect preditions and 41+30 incorrect predictions 
#############################################################################

from sklearn.metrics import classification_report
print(classification_report(y_test1, y_pred))

# %%
#############################################################################
GUI 
#############################################################################

Ecom_Data=pd.read_csv("C:/Users/dell/Downloads/Ecom.csv")
Ecom_Data

Ey_Data

# creating another data set
Ey_Data = Ecom_Data
Ey_Data = Ey_Data.fillna(method='pad')
Ey_Data.isnull().sum()

y=len(Ey_Data.columns)
y

Ey_Data.columns

# New code # using label encoder & for loop converting to factors above defined columns
lb_make = LabelEncoder()
for i in range(y):
    Ey_Data[Ecom_Data.columns[i]] = lb_make.fit_transform(Ey_Data[Ecom_Data.columns[i]])
    i+=1
print("its done")

X=Ey_Data[['monthly visit','months spend amount','mode of the payment','Time spending amount','Visting time','Shopping type preference']]
Y=Ey_Data['Gender']

# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X,Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

monthlyvisit={'0_1':0,'4_feb':1,'6_may':2,'8_july':3,'10_sep':4}
monthlyvisit
monthsspendamount={'1000-2500':0,'500-1000':1,'above500':2} 
modeofthepayment={'cash on delivery':0,'credit cards':1,'debit cards':2,'speciality vouchers':4,'net banking':3}
Timespendingamount={'16-30':0,'31-45':1,'46-60':2,'more than 60':3}
Vistingtime={'working days':4,'weekends':3,'Holidays':0,'fortnightly':1,'monthly':2}
Shoppingtypepreference={'12 to 3pm':0,'3 to 6pm':1,'after 6pm':2}
Gender={'Female':0,'male':1}
Monthlyvisit

model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)

from sklearn import linear_model
import tkinter as tk 
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

X=Ey_Data[['monthly visit','months spend amount','mode of the payment','Time spending amount','Visting time','Shopping type preference']].astype(float)
Y=Ey_Data['Gender'].astype(float)

# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# tkinter GUI
root= tk.Tk()
root.title("Reachout Analytics")
canvas1 = tk.Canvas(root, width = 500, height = 300)
canvas1.pack()

# with sklearn
#Intercept_result = ('Intercept: ', regr.intercept_)
#label_Intercept = tk.Label(root, text=Intercept_result, justify = 'center')
#canvas1.create_window(260, 220, window=label_Intercept)

# with sklearn
#Coefficients_result  = ('Coefficients: ', regr.coef_)
#label_Coefficients = tk.Label(root, text=Coefficients_result, justify = 'center')
#canvas1.create_window(260, 240, window=label_Coefficients)

Ey_Data.columns

# New_monthly visit label and input box
label1 = tk.Label(root, text='monthly visit : ')
canvas1.create_window(100, 100, window=label1)

entry1 = tk.Entry (root) # create 1st entry box
canvas1.create_window(270, 100, window=entry1)

# New_months spend amount label and input box
label2 = tk.Label(root, text='months spend amount : ')
canvas1.create_window(100, 120, window=label2)

entry2 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)

# New_mode of the payment label and input box
label3 = tk.Label(root, text=' mode of the payment : ')
canvas1.create_window(100, 140, window=label3)

entry3 = tk.Entry (root) # create 3rd entry box
canvas1.create_window(270, 140, window=entry3)

# New_Time spending amountlabel and input box
label4 = tk.Label(root, text=' Time spending amount: ')
canvas1.create_window(100, 160, window=label4)

entry4 = tk.Entry (root) # create 4th entry box
canvas1.create_window(270, 160, window=entry4)

# New_Visting time label and input box
label5 = tk.Label(root, text=' Visting time: ')
canvas1.create_window(100, 180, window=label5)

entry5 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 180, window=entry5)

# New_Shopping type preference label and input box
label6 = tk.Label(root, text=' Shopping type preference : ')
canvas1.create_window(100, 200, window=label6)

entry6 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 200, window=entry6)




def values(): 
    global New_monthlyvisit #our 1st input variable
    New_monthlyvisit = float(entry1.get()) 
    
    global New_monthsspendamount#our 2nd input variable
    New_monthsspendamount= float(entry2.get())
    
    global New_modeofthepayment #our 2nd input variable
    New_modeofthepayment= float(entry3.get()) 
    
    global New_Timespendingamount #our 2nd input variable
    New_Timespendingamount= float(entry4.get())
    
    global  New_Vistingtime#our 2nd input variable
    New_Vistingtime = float(entry5.get()) 
    
    global New_Shoppingtypepreference #our 2nd input variable
    New_Shoppingtypepreference = float(entry6.get()) 
    
    Prediction_result  = ('Predicted Gender: ', regr.predict([[New_monthlyvisit,New_monthsspendamount,New_modeofthepayment,New_Timespendingamount,New_Vistingtime,New_Shoppingtypepreference]]))
    label_Prediction = tk.Label(root, text= Prediction_result, bg='orange')
    canvas1.create_window(260, 270, window=label_Prediction)
     
        
button1 = tk.Button (root, text='Predict Gender',command=values, bg='orange') # button to call the 'values' command above 
canvas1.create_window(260, 280, window=button1)


root.mainloop()
